# %% [markdown]
# ## 1. Loading the libraries

# %%
import os
import cv2
import time
import pandas as pd
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from keras.optimizers import Adam

dataset_path = r"/content/drive/MyDrive/Mask_detection_Dataset/dataset/"
# Define the categories
categories = ['without_mask',
              'with_mask']

# %% [markdown]
# ## 2. Plotting number of images per feature from our dataset

# %%
# Function to count images in each category and plot a bar graph
def plot_category_counts(dataset_path, categories):
    # Lists to store category names and image counts
    category_names = []
    image_counts = []

    # Iterate over each category to count the images
    for category in categories:
        image_dir = os.path.join(dataset_path, category)
        num_images = len(os.listdir(image_dir))

        category_names.append(category)
        image_counts.append(num_images)

    # Plotting the bar graph
    plt.figure(figsize=(10, 6))
    plt.bar(category_names, image_counts, color='skyblue')
    plt.xlabel('Category', fontsize=14)
    plt.ylabel('Number of Images', fontsize=14)
    plt.title('Number of Images per Category', fontsize=16)
    plt.xticks(rotation=45)  # Rotate category names for better readability
    plt.show()

# Now, call the function with your dataset path and categories
plot_category_counts(dataset_path, categories)

# %% [markdown]
# ## 3. Setting Up Image Data Generators for Binary Classification in Keras

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # Use 20% of the data for validation
)

train_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(320, 320),
    batch_size=32,
    class_mode='binary',  # Adjusted for binary classification
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(320, 320),
    batch_size=32,
    class_mode='binary',  # Adjusted for binary classification
    subset='validation'
)
# Out:
# Found 6400 images belonging to 2 classes.
# Found 1598 images belonging to 2 classes.

# %% [markdown]
# ## 4. Printing the feature names to verify if the generators were setup correctly.

# %%
# Accessing class_indices attribute
class_indices = validation_generator.class_indices

# Getting class names from the class_indices dictionary
class_names = list(class_indices.keys())

# Printing class names
print("Class names in the training generator:")
for name in class_names:
    print(name)
# Out:
# Class names in the training generator:
# with_mask
# without_mask

# %% [markdown]
# ## 5. printing 1 image from validation and train generators for verification.

# %%
# Get a batch of images and labels from the train_generator
images, labels = next(train_generator)

# Plot the first image in the batch
plt.imshow(images[0])
plt.title("Sample Image from Train Generator")
plt.axis('off')  # Turn off axis labels and ticks
plt.show()

# If you also want to display the label for this image
print("Label for this image:", labels[0])


# Get a batch of images and labels from the train_generator
images, labels = next(validation_generator)

# Plot the first image in the batch
plt.imshow(images[0])
plt.title("Sample Image from Validation Generator")
plt.axis('off')  # Turn off axis labels and ticks
plt.show()

# If you also want to display the label for this image
print("Label for this image:", labels[0])
# Out:
# Label for this image: 0.0
# Label for this image: 0.0

# %% [markdown]
# ## 6. Loading a Pre-trained ResNet50 Model as Feature Extractor in Keras

# %%
# Load the base model
base_model = ResNet50(include_top=False, weights='imagenet', input_shape=(320, 320, 3), pooling='avg')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 3s 0us/step

# %% [markdown]
# ## 7. Fine-Tuning and Compiling the Pre-trained ResNet50 Model for Binary Classification

# %%
# Unfreeze the top 100 layers of the base model
base_model.trainable = True  # Make the base model trainable
for layer in base_model.layers[:-100]:
    layer.trainable = False  # Freeze layers except for the last 100

# Adding custom layers on top of the base model
x = base_model.output
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)  # Binary classification layer

# Defining the model
model = Model(inputs=base_model.input, outputs=predictions)

# Compilation with a suitable learning rate for fine-tuning
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Setting up callbacks for training
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True),
    ModelCheckpoint('/content/drive/MyDrive/MaskDetection/best_pretrainednn_model', monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1)
]

# %% [markdown]
# ## 8. Training and Saving a Fine-Tuned Model for Binary Classification

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=100,
    validation_data=validation_generator,
    callbacks=callbacks)


model.save('/content/drive/MyDrive/MaskDetection/final_pretrainednn_model')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0816 - accuracy: 0.9706
# Epoch 1: val_loss improved from inf to 4.49456, saving model to /content/drive/MyDrive/MaskDetection/best_pretrainednn_model
# 200/200 [==============================] - 1940s 9s/step - loss: 0.0816 - accuracy: 0.9706 - val_loss: 4.4946 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9903
# Epoch 2: val_loss improved from 4.49456 to 0.59100, saving model to /content/drive/MyDrive/MaskDetection/best_pretrainednn_model
# 200/200 [==============================] - 121s 607ms/step - loss: 0.0268 - accuracy: 0.9903 - val_loss: 0.5910 - val_accuracy: 0.8198 - lr: 1.0000e-04
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9948
# Epoch 3: val_loss did not improve from 0.59100
# 200/200 [==============================] - 90s 449ms/step - loss: 0.0132 - accuracy: 0.9948 - val_loss: 3.7965 - val_accuracy: 0.5181 - lr: 1.0000e-04
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9939
# Epoch 4: val_loss did not improve from 0.59100
# 200/200 [==============================] - 90s 451ms/step - loss: 0.0177 - accuracy: 0.9939 - val_loss: 2.1796 - val_accuracy: 0.6802 - lr: 1.0000e-04
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9945
# Epoch 5: val_loss improved from 0.59100 to 0.25255, saving model to /content/drive/MyDrive/MaskDetection/best_pretrainednn_model
# 200/200 [==============================] - 111s 556ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.2525 - val_accuracy: 0.9287 - lr: 1.0000e-04
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9941
# Epoch 6: val_loss improved from 0.25255 to 0.22892, saving model to /content/drive/MyDrive/MaskDetection/best_pretrainednn_model
# 200/200 [==============================] - 109s 546ms/step - loss: 0.0173 - accuracy: 0.9941 - val_loss: 0.2289 - val_accuracy: 0.9005 - lr: 1.0000e-04
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9973
# Epoch 7: val_loss did not improve from 0.22892
# 200/200 [==============================] - 91s 455ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.3751 - val_accuracy: 0.8229 - lr: 1.0000e-04
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9977
# Epoch 8: val_loss improved from 0.22892 to 0.03208, saving model to /content/drive/MyDrive/MaskDetection/best_pretrainednn_model
# 200/200 [==============================] - 112s 562ms/step - loss: 0.0059 - accuracy: 0.9977 - val_loss: 0.0321 - val_accuracy: 0.9894 - lr: 1.0000e-04
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9969
# Epoch 9: val_loss did not improve from 0.03208
# 200/200 [==============================] - 83s 416ms/step - loss: 0.0117 - accuracy: 0.9969 - val_loss: 3.9928 - val_accuracy: 0.5006 - lr: 1.0000e-04
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9967
# Epoch 10: val_loss did not improve from 0.03208
# 200/200 [==============================] - 92s 461ms/step - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.0477 - val_accuracy: 0.9831 - lr: 1.0000e-04
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9997
# Epoch 11: val_loss did not improve from 0.03208
# 200/200 [==============================] - 88s 441ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0749 - val_accuracy: 0.9875 - lr: 1.0000e-04
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9964
# Epoch 12: val_loss did not improve from 0.03208
# 200/200 [==============================] - 90s 451ms/step - loss: 0.0120 - accuracy: 0.9964 - val_loss: 26.3099 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 13/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9980Restoring model weights from the end of the best epoch: 8.
#
# Epoch 13: val_loss did not improve from 0.03208
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 0.1451 - val_accuracy: 0.9556 - lr: 1.0000e-04
# Epoch 13: early stopping
